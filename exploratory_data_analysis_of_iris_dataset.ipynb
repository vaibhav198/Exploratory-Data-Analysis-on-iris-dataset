# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %% [markdown]
# # Let's see missing values and handle it.

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
sns.heatmap(df.isnull(), yticklabels= False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### from the above graph we can say there is no missing value for any any feature

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### all the features are of float64 type except one 'species' which of type Object

# %% [markdown]
# # Let's perform some plots

# %% [markdown]
# #### Pair plot

# %%
sns.pairplot(df)

# %% [markdown]
# #### Joint plot

# %%
sns.jointplot(y='sepal_length', x = 'species', data = df)

# %% [markdown]
# ## countplot

# %%
sns.countplot(x='sepal_length', data = df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='count'>

# %%
sns.countplot(x= 'sepal_width', data=df)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='count'>

# %%
sns.countplot(x= 'petal_length', data = df)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='count'>

# %%
sns.countplot(x= 'petal_width', data = df)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='count'>

# %%
sns.countplot(x= 'species', data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
df['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# ### Let's draw barplot

# %%
sns.barplot(y= 'sepal_length', x = 'species', data = df, orient = "v")
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x= 'sepal_length', y = 'species', data = df, hue =  'sepal_width', orient = "h")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %% [markdown]
# ## Perform box plot

# %%
sns.boxplot(y= 'sepal_length', x= 'species', data= df, orient = 'v')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x= 'species', y = 'sepal_width', data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# Outlier are there

# %%
sns.boxplot(x = 'species', y = 'petal_length', data= df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x= 'species', y= 'petal_width', data= df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(x= 'sepal_length', y= 'petal_length', data= df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>
